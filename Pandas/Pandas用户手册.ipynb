# %% [markdown]
# # Pandas使用指南

# %% [markdown]
# ## DataFrame和Series的区别
#
# - 二者很多功能是重叠的
#
# - 可以理解series为**1维**结构的, 当然也不完全是1维, 毕竟series还是有index, header的, Dataframe为**二维**结构, 其视觉参考就是Excel表, 具有完备的行列

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Serie

# %% [markdown]
# pandas.Series(
#
#     data=None,
#     index=None,
#     dtype=None,
#     name=None,
#     copy=False,
#     fastpath=False
# )

# %%
series = pd.Series([1, 2, 3])

# %%
series
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
series.values
# Out:
# array([1, 2, 3], dtype=int64)

# %%
series_a = pd.Series(data=[1,2,3], index=['a', 'b', 'c'], name='test')

# %%
series_a
# Out:
# a    1
# b    2
# c    3
# Name: test, dtype: int64

# %%
series_a.name
# Out:
# 'test'

# %%
series_a.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
series_a.dtype
# Out:
# dtype('int64')

# %% [markdown]
# 显然不能单纯认为series是类似于一维列表\[\]的数据结构

# %% [markdown]
# ### Series转Dataframe

# %%
s_df = series_a.to_frame()

# %%
s_df
# Out:
#    test
# a     1
# b     2
# c     3

# %% [markdown]
# ### Series转字典

# %%
series_a.to_dict()
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
sites = {1: "google", 2: "facebook", 3: "wikipedia"}

pd.Series(sites, index = [1, 2], name="test" )
# Out:
# 1      google
# 2    facebook
# Name: test, dtype: object

# %%
pd.Series(sites, index = [1, 2, 3], name="test" )
# Out:
# 1       google
# 2     facebook
# 3    wikipedia
# Name: test, dtype: object

# %% [markdown]
# ### 操作和访问

# %%
series_a[0]
# Out:
# 1

# %%
series_a[[0, 1]]
# Out:
# a    1
# b    2
# Name: test, dtype: int64

# %%
series_a.iloc[0]
# Out:
# 1

# %%
series_a.iloc[0: 3]
# Out:
# a    1
# b    2
# c    3
# Name: test, dtype: int64

# %%
series.drop(0)
# Out:
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# ### 合并Series

# %%
pd.concat(
    [
        pd.Series(data = [9,0]), 
        pd.Series(data=[11,13])
    ], 
    ignore_index=True
)
# Out:
# 0     9
# 1     0
# 2    11
# 3    13
# dtype: int64

# %% [markdown]
# ## Dataframe

# %% [markdown]
# pd.DataFrame(
#
#     data=None,
#     index: 'Axes | None' = None,
#     columns: 'Axes | None' = None,
#     dtype: 'Dtype | None' = None,
#     copy: 'bool | None' = None,
# )

# %%
# 一维
pd.DataFrame([1,3,5])
# Out:
#    0
# 0  1
# 1  3
# 2  5

# %%
# 转置
pd.DataFrame([1,3,5]).T
# Out:
#    0  1  2
# 0  1  3  5

# %%
# 二维结构
pd.DataFrame([[1,3,5]])
# Out:
#    0  1  2
# 0  1  3  5

# %%
pd.DataFrame([[1,3,4], [25, 65, 12]])
# Out:
#     0   1   2
# 0   1   3   4
# 1  25  65  12

# %%
dic = {
    'a': [1, 2, 3],
    'b': [5, 7, 9]
}
pd.DataFrame(dic)
# Out:
#    a  b
# 0  1  5
# 1  2  7
# 2  3  9

# %%
df = pd.DataFrame(dic)

# %% [markdown]
# ### 增加一列

# %%
df['c'] = ['aa', np.nan, np.inf]

# %%
df['n'] = [*'poqd']

# %%
df
# Out:
#    m  a  b     c   d    e   k  n
# 0  0  1  5    aa  bb  bbb   6  p
# 1  0  2  7   NaN  bb  bbb   9  o
# 2  0  3  9   inf  aa  aaa  12  q
# 3  0  4  6  test  bb  bbb  10  d

# %% [markdown]
# ### 增加一行

# %%
df.loc[3] = [4, 6, 'test']

# %%
# 注意二者的差异
df.iloc[4] = [10, 16, 'abc']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df.iloc[4] = [10, 16, 'abc']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:713, in _LocationIndexer.__setitem__(self, key, value)
#     711     key = com.apply_if_callable(key, self.obj)
#     712 indexer = self._get_setitem_indexer(key)
# --> 713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
#     716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1413, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1411 elif is_integer(i):
#    1412     if i >= len(ax):
# -> 1413         raise IndexError("iloc cannot enlarge its target object")
#    1414 elif isinstance(i, dict):
#    1415     raise IndexError("iloc cannot enlarge its target object")
#
# IndexError: iloc cannot enlarge its target object

# %%
df
# Out:
#    a  b     c
# 0  1  5    aa
# 1  2  7   NaN
# 2  3  9   inf
# 3  4  6  test

# %% [markdown]
# ### 删除行列

# %% [markdown]
# pop是直接操作源数据

# %%
df.pop('a')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df
# Out:
#    m  b     c   d    e   k  n
# 0  0  5    aa  bb  bbb   6  p
# 1  0  7   NaN  bb  bbb   9  o
# 2  0  9   inf  aa  aaa  12  q
# 3  0  6  test  bb  bbb  10  d

# %% [markdown]
# df.drop(
#
#     labels=None,
#     axis: 'Axis' = 0,
#     index=None,
#     columns=None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'str' = 'raise',
# )

# %%
# 并不会操作源数据, 而是返回一个新的数据

df.drop(2)
# Out:
#    m  b     c   d    e   k  n
# 0  0  5    aa  bb  bbb   6  p
# 1  0  7   NaN  bb  bbb   9  o
# 3  0  6  test  bb  bbb  10  d

# %%
df
# Out:
#    m  b     c   d    e   k  n
# 0  0  5    aa  bb  bbb   6  p
# 1  0  7   NaN  bb  bbb   9  o
# 2  0  9   inf  aa  aaa  12  q
# 3  0  6  test  bb  bbb  10  d

# %% [markdown]
# ### map
#
# - 作用于列

# %%
df['d'] = df['b'].map(lambda x: 'aa' if x > 7 else 'bb')

# %%
df
# Out:
#    a  b     c   d
# 0  1  5    aa  bb
# 1  2  7   NaN  bb
# 2  3  9   inf  aa
# 3  4  6  test  bb

# %% [markdown]
# ### appply
#
# - 基于Serie
#
# - 基于整个Dataframe
#
# - 作用于列, 多列

# %%
df['e'] = df['b'].map(lambda x: 'aaa' if x > 7 else 'bbb')

# %%
df
# Out:
#    a  b     c   d    e
# 0  1  5    aa  bb  bbb
# 1  2  7   NaN  bb  bbb
# 2  3  9   inf  aa  aaa
# 3  4  6  test  bb  bbb

# %%
def test(a, c):
    return a + c

# %%
df['k'] = df.apply(lambda c: test(c['a'], c['b']), axis=1)

# %%
df
# Out:
#    a  b     c   d    e   k
# 0  1  5    aa  bb  bbb   6
# 1  2  7   NaN  bb  bbb   9
# 2  3  9   inf  aa  aaa  12
# 3  4  6  test  bb  bbb  10

# %% [markdown]
# ### applymap
#
# - 作用于全局

# %%
df.applymap(lambda x: str(x), na_action='ignore').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   m       4 non-null      object
#  1   b       4 non-null      object
#  2   c       3 non-null      object
#  3   d       4 non-null      object
#  4   e       4 non-null      object
#  5   k       4 non-null      object
#  6   n       4 non-null      object
# dtypes: object(7)
# memory usage: 428.0+ bytes

# %% [markdown]
# ### assign
#
# - 同时创建多列

# %% [markdown]
# Assign new columns to a DataFrame.
#
# Returns a new object with all original columns in addition to new ones.
# Existing columns that are re-assigned will be overwritten.

# %%
df.assign(g = lambda x: x.a + 1, f = lambda x: x.b * 2)
# Out:
#    a  b     c   d    e  g   f
# 0  1  5    aa  bb  bbb  2  10
# 1  2  7   NaN  bb  bbb  3  14
# 2  3  9   inf  aa  aaa  4  18
# 3  4  6  test  bb  bbb  5  12

# %% [markdown]
# ### insert
#
# - 在指定位置插入数据

# %% [markdown]
# pd.DataFrame.insert(
#
#     self,
#     loc: 'int',
#     column: 'Hashable',
#     value: 'Scalar | AnyArrayLike',
#     allow_duplicates: 'bool' = False,
# ) -> 'None'

# %%
df.insert(0, 'm', 0)

# %%
df
# Out:
#    m  a  b     c   d    e   k
# 0  0  1  5    aa  bb  bbb   6
# 1  0  2  7   NaN  bb  bbb   9
# 2  0  3  9   inf  aa  aaa  12
# 3  0  4  6  test  bb  bbb  10

# %% [markdown]
# ### rename
#
# - 变更表头

# %% [markdown]
# pd.DataFrame.rename(
#
#     self,
#     mapper: 'Renamer | None' = None,
#     *,
#     index: 'Renamer | None' = None,
#     columns: 'Renamer | None' = None,
#     axis: 'Axis | None' = None,
#     copy: 'bool' = True,
#     inplace: 'bool' = False,
#     level: 'Level | None' = None,
#     errors: 'str' = 'ignore',
# ) -> 'DataFrame | None'

# %%
tmp = df.copy(True)

# %%
tmp
# Out:
#    m  a  b     c   d    e   k
# 0  0  1  5    aa  bb  bbb   6
# 1  0  2  7   NaN  bb  bbb   9
# 2  0  3  9   inf  aa  aaa  12
# 3  0  4  6  test  bb  bbb  10

# %%
tmp.rename(columns={'a': 'a_test', 'b': 'b_test'})
# Out:
#    m  a_test  b_test     c   d    e   k
# 0  0       1       5    aa  bb  bbb   6
# 1  0       2       7   NaN  bb  bbb   9
# 2  0       3       9   inf  aa  aaa  12
# 3  0       4       6  test  bb  bbb  10

# %%
b = tmp.copy(True)

# %%
b.columns = [*'abcdef']

# %%
b
# Out:
#      a  b  c     d   e   f
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %% [markdown]
# b.reindex(
#
#     labels=None,
#     index=None,
#     columns=None,
#     axis=None,
#     method=None,
#     copy=True,
#     level=None,
#     fill_value=nan,
#     limit=None,
#     tolerance=None,
# )

# %%
b.reindex(index=[*'abcd'])
# Out:
# C:\Users\Lian\AppData\Local\Temp\ipykernel_15128\2625705151.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   b.reindex(index=[*'abcd'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [150], in <cell line: 1>()
# ----> 1 b.reindex(index=[*'abcd'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4804, in DataFrame.reindex(self, *args, **kwargs)
#    4802 kwargs.pop("axis", None)
#    4803 kwargs.pop("labels", None)
# -> 4804 return super().reindex(**kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4966, in NDFrame.reindex(self, *args, **kwargs)
#    4963     return self._reindex_multi(axes, copy, fill_value)
#    4965 # perform the reindex on the axes
# -> 4966 return self._reindex_axes(
#    4967     axes, level, limit, tolerance, method, fill_value, copy
#    4968 ).__finalize__(self, method="reindex")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4623, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4621 index = axes["index"]
#    4622 if index is not None:
# -> 4623     frame = frame._reindex_index(
#    4624         index, method, copy, level, fill_value, limit, tolerance
#    4625     )
#    4627 return frame
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4642, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4629 def _reindex_index(
#    4630     self,
#    4631     new_index,
#    (...)
#    4637     tolerance=None,
#    4638 ):
#    4639     new_index, indexer = self.index.reindex(
#    4640         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4641     )
# -> 4642     return self._reindex_with_indexers(
#    4643         {0: [new_index, indexer]},
#    4644         copy=copy,
#    4645         fill_value=fill_value,
#    4646         allow_dups=False,
#    4647     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:679, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
# --> 679     self.axes[axis]._validate_can_reindex(indexer)
#     681 if axis >= self.ndim:
#     682     raise IndexError("Requested axis not found in manager")
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4107, in Index._validate_can_reindex(self, indexer)
#    4105 # trying to reindex on an axis with duplicates
#    4106 if not self._index_as_unique and len(indexer):
# -> 4107     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
b.reindex(labels=[*'abcd'])
# Out:
# C:\Users\Lian\AppData\Local\Temp\ipykernel_15128\2521675775.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   b.reindex(labels=[*'abcd'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [151], in <cell line: 1>()
# ----> 1 b.reindex(labels=[*'abcd'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4804, in DataFrame.reindex(self, *args, **kwargs)
#    4802 kwargs.pop("axis", None)
#    4803 kwargs.pop("labels", None)
# -> 4804 return super().reindex(**kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4966, in NDFrame.reindex(self, *args, **kwargs)
#    4963     return self._reindex_multi(axes, copy, fill_value)
#    4965 # perform the reindex on the axes
# -> 4966 return self._reindex_axes(
#    4967     axes, level, limit, tolerance, method, fill_value, copy
#    4968 ).__finalize__(self, method="reindex")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4623, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4621 index = axes["index"]
#    4622 if index is not None:
# -> 4623     frame = frame._reindex_index(
#    4624         index, method, copy, level, fill_value, limit, tolerance
#    4625     )
#    4627 return frame
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4642, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4629 def _reindex_index(
#    4630     self,
#    4631     new_index,
#    (...)
#    4637     tolerance=None,
#    4638 ):
#    4639     new_index, indexer = self.index.reindex(
#    4640         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4641     )
# -> 4642     return self._reindex_with_indexers(
#    4643         {0: [new_index, indexer]},
#    4644         copy=copy,
#    4645         fill_value=fill_value,
#    4646         allow_dups=False,
#    4647     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:679, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
# --> 679     self.axes[axis]._validate_can_reindex(indexer)
#     681 if axis >= self.ndim:
#     682     raise IndexError("Requested axis not found in manager")
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4107, in Index._validate_can_reindex(self, indexer)
#    4105 # trying to reindex on an axis with duplicates
#    4106 if not self._index_as_unique and len(indexer):
# -> 4107     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
# 当其他列的表头和index的同名, 需要使用drop删除掉重名冲突
b.reset_index(inplace=True, drop=True)

# %%
# 注意这款里的操作
b.reindex([*'abcd'])
# Out:
#     a   b   c    d    e   f
# a NaN NaN NaN  NaN  NaN NaN
# b NaN NaN NaN  NaN  NaN NaN
# c NaN NaN NaN  NaN  NaN NaN
# d NaN NaN NaN  NaN  NaN NaN

# %% [markdown]
# Create a new index and reindex the dataframe. By default values in the new index that do not have corresponding records in the dataframe are assigned NaN.
#
# 注意这里, 假如新的index没有对应的项, 将被写nan覆盖

# %%
b.reindex([0,2,3,1])
# Out:
#    a  b  c     d   e   f
# 0  0  1  5    aa  bb   6
# 2  0  3  9   inf  aa  12
# 3  0  4  6  test  bb  10
# 1  0  3  7   NaN  bb   9

# %%
b.reindex([0,2,3,5])
# Out:
#      a    b    c     d    e     f
# 0  0.0  1.0  5.0    aa   bb   6.0
# 2  0.0  3.0  9.0   inf   aa  12.0
# 3  0.0  4.0  6.0  test   bb  10.0
# 5  NaN  NaN  NaN   NaN  NaN   NaN

# %%
index = ['Firefox', 'Chrome', 'Safari', 'IE10', 'Konqueror']
dfi = pd.DataFrame({'http_status': [200, 200, 404, 404, 301],
                  'response_time': [0.04, 0.02, 0.07, 0.08, 1.0]},
                  index=index)

# %%
dfi
# Out:
#            http_status  response_time
# Firefox            200           0.04
# Chrome             200           0.02
# Safari             404           0.07
# IE10               404           0.08
# Konqueror          301           1.00

# %%
new_index = ['Safari', 'Iceweasel', 'Comodo Dragon', 'IE10',
             'Chrome']
dfi.reindex(new_index)
# Out:
#                http_status  response_time
# Safari               404.0           0.07
# Iceweasel              NaN            NaN
# Comodo Dragon          NaN            NaN
# IE10                 404.0           0.08
# Chrome               200.0           0.02

# %% [markdown]
# ### index
#
# - 列, index, 即表头
#
# - 行, index. 行号

# %% [markdown]
# tmp.set_index(
#
#     keys,
#     drop: 'bool' = True,
#     append: 'bool' = False,
#     inplace: 'bool' = False,
#     verify_integrity: 'bool' = False,
# )

# %%
tmp.set_index('e', inplace=True)

# %%
tmp
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  2  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %% [markdown]
# tmp.reset_index(
#
#     level: 'Hashable | Sequence[Hashable] | None' = None,
#     drop: 'bool' = False,
#     inplace: 'bool' = False,
#     col_level: 'Hashable' = 0,
#     col_fill: 'Hashable' = '',
# ) -> 'DataFrame | None'

# %%
# reset之后, index的位置被移动到第一列
tmp.reset_index()
# Out:
#      e  m  a  b     c   d   k
# 0  bbb  0  1  5    aa  bb   6
# 1  bbb  0  2  7   NaN  bb   9
# 2  aaa  0  3  9   inf  aa  12
# 3  bbb  0  4  6  test  bb  10

# %% [markdown]
# ### 转置

# %%
# 原有的index将直接覆盖
tmp.set_index('d')
# Out:
#     m  a  b     c   k
# d
# bb  0  1  5    aa   6
# bb  0  2  7   NaN   9
# aa  0  3  9   inf  12
# bb  0  4  6  test  10

# %%
tmp.set_index('d').T
# Out:
# d  bb   bb   aa    bb
# m   0    0    0     0
# a   1    2    3     4
# b   5    7    9     6
# c  aa  NaN  inf  test
# k   6    9   12    10

# %% [markdown]
# ### 排序

# %% [markdown]
# pd.DataFrame.sort_values(
#
#     self,
#     by,
#     axis: 'Axis' = 0,
#     ascending=True,
#     inplace: 'bool' = False,
#     kind: 'str' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc' = None,
# )

# %%
tmp
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %%
tmp.sort_values(by=['a'], ascending=False)
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  4  6  test  bb  10
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  1  5    aa  bb   6

# %%
tmp.sort_values(by=['a', 'b'], ascending=False)
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  4  6  test  bb  10
# aaa  0  3  9   inf  aa  12
# bbb  0  3  7   NaN  bb   9
# bbb  0  1  5    aa  bb   6

# %%
# 对多列的数据进行不同顺序的排序
tmp.sort_values(by=['a', 'b'], ascending=[False, True])
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  4  6  test  bb  10
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  1  5    aa  bb   6

# %% [markdown]
# pd.DataFrame.sort_index(
#
#     self,
#     axis: 'Axis' = 0,
#     level: 'Level | None' = None,
#     ascending: 'bool | int | Sequence[bool | int]' = True,
#     inplace: 'bool' = False,
#     kind: 'str' = 'quicksort',
#     na_position: 'str' = 'last',
#     sort_remaining: 'bool' = True,
#     ignore_index: 'bool' = False,
#     key: 'IndexKeyFunc' = None,
# )

# %%
a = tmp.copy(True)

# %%
a
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %%
# 对表头进行排序
a.sort_index(axis=1)
# Out:
#      a  b     c   d   k  m
# e
# bbb  1  5    aa  bb   6  0
# bbb  3  7   NaN  bb   9  0
# aaa  3  9   inf  aa  12  0
# bbb  4  6  test  bb  10  0

# %%
# 对行排序
a.sort_index()
# Out:
#      m  a  b     c   d   k
# e
# aaa  0  3  9   inf  aa  12
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7   NaN  bb   9
# bbb  0  4  6  test  bb  10

# %% [markdown]
# ### 属性

# %%
# 唯一值
a['d'].unique()
# Out:
# array(['bb', 'aa'], dtype=object)

# %%
# 唯一值
a['d'].nunique()
# Out:
# 2

# %%
# 最大值
a['a'].max()
# Out:
# 4

# %%
# 返回最大值的index(label)
a['a'].idxmax()
# Out:
# 'bbb'

# %%
a
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %% [markdown]
# 填充nan值

# %%
a['c'].fillna(value=0, inplace=True)

# %%
a
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7     0  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %% [markdown]
# 等价于, a.ffill?
#
# > Synonym for DataFrame.fillna() with method='ffill'.

# %%
# 字典转换
a.set_index('d')['k'].to_dict()
# Out:
# {'bb': 10, 'aa': 12}

# %% [markdown]
# ### inf & nan

# %%
# 查看空值
df.isna()
# Out:
#        m      b      c      d      e      k      n
# 0  False  False  False  False  False  False  False
# 1  False  False   True  False  False  False  False
# 2  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False

# %%
df.isnull()
# Out:
#        m      b      c      d      e      k      n
# 0  False  False  False  False  False  False  False
# 1  False  False   True  False  False  False  False
# 2  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False

# %%
1 + np.inf
# Out:
# inf

# %%
1 + np.nan
# Out:
# nan

# %%
np.nan + np.inf
# Out:
# nan

# %%
np.NINF + np.PINF
# Out:
# nan

# %% [markdown]
# nan值参与的所有计算, 结果都是nan值

# %% [markdown]
# ### groupby

# %%
item_dic = {}

with open(
    'FS_Comins[DES][xls].txt', 
    encoding='utf-8',
    mode='r'
) as f:
    for line in f.readlines():
        key = line[0: line.index(' ')]
        value = line[line.index('[') + 1 : line.index(']')]
        info = line[line.index(']')+ 1:].strip()
        item_dic[key] = value

# %%
finc = pd.read_csv('FS_Comins(1).csv')

# %%
finc.rename(columns=item_dic, inplace=True)

# %%
finc.head()
# Out:
#    证券代码        会计期间 报表类型         营业总收入  营业收入         利息净收入          利息收入  \
# 0     1  2005-12-31    A  4.557763e+09   NaN  4.133321e+09  7.879988e+09
# 1     1  2006-12-31    A  6.788986e+09   NaN  6.482444e+09  1.155122e+10
# 2     1  2007-12-31    A  1.029153e+10   NaN  9.605849e+09  1.804390e+10
# 3     1  2008-12-31    A  1.356322e+10   NaN  1.259789e+10  2.646526e+10
# 4     1  2009-12-31    A  1.429386e+10   0.0  1.298437e+10  2.198551e+10
#
#            利息支出  已赚保费  保险业务收入  ...  归属少数股东的综合收益  研发费用  其中：利息费用(财务费用)  \
# 0  3.746667e+09   NaN     NaN  ...          NaN   NaN            NaN
# 1  5.068773e+09   0.0     0.0  ...          NaN   NaN            NaN
# 2  8.438051e+09   0.0     0.0  ...          NaN   NaN            NaN
# 3  1.386738e+10   0.0     0.0  ...          NaN   NaN            NaN
# 4  9.001138e+09   0.0     0.0  ...          NaN   NaN            NaN
#
#    其中：利息收入(财务费用)  其他收益  其中：以摊余成本计量的金融资产终止确认收益  净敞口套期收益  信用减值损失  资产处置收益  \
# 0            NaN   NaN                    NaN      NaN     NaN     NaN
# 1            NaN   NaN                    NaN      NaN     NaN     NaN
# 2            NaN   NaN                    NaN      NaN     NaN     NaN
# 3            NaN   NaN                    NaN      NaN     NaN     NaN
# 4            NaN   NaN                    NaN      NaN     NaN     NaN
#
#    归属于母公司其他权益工具持有者的净利润
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 72 columns]

# %%
finc['year'] = finc['会计期间'].map(lambda x: x[:4])

# %% [markdown]
# 筛选出历年营业收入排名前三的企业

# %%
finc.sort_values(by=['营业总收入'], ascending=False).groupby(by=['year']).head(3)
# Out:
#       证券代码        会计期间 报表类型         营业总收入          营业收入         利息净收入  \
# 33       2  2021-12-31    A  4.527980e+11  4.527980e+11           NaN
# 32       2  2020-12-31    A  4.191120e+11  4.191120e+11           NaN
# 31       2  2019-12-31    A  3.678940e+11  3.678940e+11           NaN
# 1235   333  2021-12-31    A  3.433610e+11  3.412330e+11  2.127043e+09
# 30       2  2018-12-31    A  2.976790e+11  2.976790e+11           NaN
# 1234   333  2020-12-31    A  2.857100e+11  2.842210e+11  1.488211e+09
# 1233   333  2019-12-31    A  2.793810e+11  2.782160e+11  1.163180e+09
# 1232   333  2018-12-31    A  2.618200e+11  2.596650e+11  2.154392e+09
# 29       2  2017-12-31    A  2.428970e+11  2.428970e+11           NaN
# 1231   333  2017-12-31    A  2.416680e+11  2.407120e+11  9.556570e+08
# 28       2  2016-12-31    A  2.404770e+11  2.404770e+11  0.000000e+00
# 4684   725  2021-12-31    A  2.193100e+11  2.193100e+11           NaN
# 3700   651  2019-12-31    A  2.005080e+11  1.981530e+11  2.351472e+09
# 3699   651  2018-12-31    A  2.000240e+11  1.981230e+11  1.899288e+09
# 1249   338  2020-12-31    A  1.974910e+11  1.974910e+11           NaN
# 27       2  2015-12-31    A  1.955490e+11  1.955490e+11  0.000000e+00
# 1230   333  2016-12-31    A  1.593990e+11  1.590440e+11  3.498070e+08
# 1246   338  2017-12-31    A  1.515690e+11  1.515690e+11           NaN
# 26       2  2014-12-31    A  1.463880e+11  1.463880e+11  0.000000e+00
# 1228   333  2014-12-31    A  1.419050e+11  1.416680e+11  2.279978e+08
# 3695   651  2014-12-31    A  1.392950e+11  1.377500e+11  1.544287e+09
# 1229   333  2015-12-31    A  1.387830e+11  1.384410e+11  3.386470e+08
# 25       2  2013-12-31    A  1.354190e+11  1.354190e+11  0.000000e+00
# 4436   709  2011-12-31    A  1.333440e+11  1.333440e+11  0.000000e+00
# 1227   333  2013-12-31    A  1.210600e+11  1.209750e+11  8.633246e+07
# 3694   651  2013-12-31    A  1.195510e+11  1.186280e+11  9.228011e+08
# 4435   709  2010-12-31    A  1.169190e+11  1.169190e+11  0.000000e+00
# 4437   709  2012-12-31    A  1.116300e+11  1.116300e+11  0.000000e+00
# 3697   651  2016-12-31    A  1.100190e+11  1.083030e+11  1.716264e+09
# 1059   100  2015-12-31    A  1.048310e+11  1.045790e+11  2.511770e+08
# 5837   825  2012-12-31    A  1.035150e+11  1.035150e+11  0.000000e+00
# 24       2  2012-12-31    A  1.031160e+11  1.031160e+11  0.000000e+00
# 5836   825  2011-12-31    A  9.622026e+10  9.622026e+10  0.000000e+00
# 2096   527  2011-12-31    A  9.310806e+10  9.310806e+10  0.000000e+00
# 5835   825  2010-12-31    A  8.719780e+10  8.719780e+10  0.000000e+00
# 4434   709  2009-12-31    A  8.718595e+10  8.718595e+10  0.000000e+00
# 884     66  2010-12-31    A  8.344443e+10  8.344443e+10  0.000000e+00
# 5833   825  2008-12-31    A  8.306286e+10  8.306286e+10  0.000000e+00
# 5832   825  2007-12-31    A  8.110475e+10  8.110475e+10  0.000000e+00
# 5834   825  2009-12-31    A  7.182836e+10  7.182836e+10  0.000000e+00
# 849     63  2009-12-31    A  6.027256e+10  6.027256e+10  0.000000e+00
# 4433   709  2008-12-31    A  5.769732e+10  5.769732e+10  0.000000e+00
# 1049   100  2005-12-31    A  5.167561e+10  5.167561e+10           NaN
# 578     39  2007-12-31    A  4.876083e+10  4.876083e+10  0.000000e+00
# 579     39  2008-12-31    A  4.732728e+10  4.732728e+10  0.000000e+00
# 1050   100  2006-12-31    A  4.685523e+10  4.685523e+10           NaN
# 4432   709  2007-12-31    A  4.179234e+10  4.179234e+10  0.000000e+00
# 5831   825  2006-12-31    A  4.008612e+10  4.008612e+10           NaN
# 577     39  2006-12-31    A  3.316780e+10  3.316780e+10           NaN
# 576     39  2005-12-31    A  3.095931e+10  3.095931e+10           NaN
# 4430   709  2005-12-31    A  2.431661e+10  2.431661e+10           NaN
#
#               利息收入          利息支出  已赚保费  保险业务收入  ...          研发费用  \
# 33             NaN           NaN   NaN     NaN  ...  6.423663e+08
# 32             NaN           NaN   NaN     NaN  ...  6.656875e+08
# 31             NaN           NaN   NaN     NaN  ...  1.066676e+09
# 1235  2.127043e+09           NaN   NaN     NaN  ...  1.201491e+10
# 30             NaN           NaN   NaN     NaN  ...  9.460644e+08
# 1234  1.488211e+09           NaN   NaN     NaN  ...  1.011867e+10
# 1233  1.163180e+09           NaN   NaN     NaN  ...  9.638137e+09
# 1232  2.154392e+09           NaN   NaN     NaN  ...  8.377201e+09
# 29             NaN           NaN   NaN     NaN  ...           NaN
# 1231  1.206582e+09  2.509250e+08   NaN     NaN  ...           NaN
# 28             NaN           NaN   0.0     0.0  ...           NaN
# 4684           NaN           NaN   NaN     NaN  ...  1.066884e+10
# 3700  2.351472e+09           NaN   NaN     NaN  ...  5.891220e+09
# 3699  1.899288e+09           NaN   NaN     NaN  ...  6.988368e+09
# 1249           NaN           NaN   NaN     NaN  ...  6.013083e+09
# 27    0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 1230  7.894140e+08  4.396070e+08   0.0     0.0  ...           NaN
# 1246           NaN           NaN   NaN     NaN  ...           NaN
# 26    0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 1228  6.325247e+08  4.045269e+08   0.0     0.0  ...           NaN
# 3695  2.254052e+09  7.097647e+08   0.0     0.0  ...           NaN
# 1229  9.001610e+08  5.615140e+08   0.0     0.0  ...           NaN
# 25    0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 4436           NaN           NaN   0.0     0.0  ...           NaN
# 1227  2.901593e+08  2.038268e+08   0.0     0.0  ...           NaN
# 3694  1.414765e+09  4.919640e+08   0.0     0.0  ...           NaN
# 4435  0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 4437  0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 3697  1.809582e+09  9.331746e+07   0.0     0.0  ...           NaN
# 1059  2.981490e+08  4.697200e+07   0.0     0.0  ...           NaN
# 5837  0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 24    0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 5836           NaN           NaN   0.0     0.0  ...           NaN
# 2096           NaN           NaN   0.0     0.0  ...           NaN
# 5835  0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 4434           NaN           NaN   0.0     0.0  ...           NaN
# 884            NaN           NaN   0.0     0.0  ...           NaN
# 5833           NaN           NaN   0.0     0.0  ...           NaN
# 5832           NaN           NaN   0.0     0.0  ...           NaN
# 5834  0.000000e+00  0.000000e+00   0.0     0.0  ...           NaN
# 849            NaN           NaN   0.0     0.0  ...           NaN
# 4433           NaN           NaN   0.0     0.0  ...           NaN
# 1049           NaN           NaN   NaN     NaN  ...           NaN
# 578            NaN           NaN   0.0     0.0  ...           NaN
# 579            NaN           NaN   0.0     0.0  ...           NaN
# 1050           NaN           NaN   NaN     NaN  ...           NaN
# 4432           NaN           NaN   0.0     0.0  ...           NaN
# 5831           NaN           NaN   NaN     NaN  ...           NaN
# 577            NaN           NaN   NaN     NaN  ...           NaN
# 576            NaN           NaN   NaN     NaN  ...           NaN
# 4430           NaN           NaN   NaN     NaN  ...           NaN
#
#       其中：利息费用(财务费用)  其中：利息收入(财务费用)          其他收益  其中：以摊余成本计量的金融资产终止确认收益  \
# 33     7.861347e+09   3.819804e+09           NaN                    NaN
# 32     8.757580e+09   4.680643e+09           NaN                    NaN
# 31     9.255269e+09   3.530405e+09           NaN                    NaN
# 1235   1.357564e+09   5.181658e+09  1.307504e+09                    NaN
# 30     8.181336e+09   3.839923e+09           NaN                    NaN
# 1234   1.305591e+09   3.663028e+09  1.424090e+09                    NaN
# 1233  -8.807030e+08   3.807136e+09  1.194665e+09              -709000.0
# 1232   7.039910e+08   2.155862e+09  1.316904e+09                    NaN
# 29              NaN            NaN           NaN                    NaN
# 1231            NaN            NaN  1.311123e+09                    NaN
# 28              NaN            NaN           NaN                    NaN
# 4684   4.866778e+09   1.050431e+09  2.092766e+09                    NaN
# 3700   1.598276e+09   3.698387e+09  9.361486e+08                    NaN
# 3699   1.068308e+09   2.384487e+09  4.085532e+08                    NaN
# 1249   1.139023e+09   1.277864e+09  3.272152e+08                    NaN
# 27              NaN            NaN           NaN                    NaN
# 1230            NaN            NaN           NaN                    NaN
# 1246            NaN            NaN  1.620389e+08                    NaN
# 26              NaN            NaN           NaN                    NaN
# 1228            NaN            NaN           NaN                    NaN
# 3695            NaN            NaN           NaN                    NaN
# 1229            NaN            NaN           NaN                    NaN
# 25              NaN            NaN           NaN                    NaN
# 4436            NaN            NaN           NaN                    NaN
# 1227            NaN            NaN           NaN                    NaN
# 3694            NaN            NaN           NaN                    NaN
# 4435            NaN            NaN           NaN                    NaN
# 4437            NaN            NaN           NaN                    NaN
# 3697            NaN            NaN           NaN                    NaN
# 1059            NaN            NaN           NaN                    NaN
# 5837            NaN            NaN           NaN                    NaN
# 24              NaN            NaN           NaN                    NaN
# 5836            NaN            NaN           NaN                    NaN
# 2096            NaN            NaN           NaN                    NaN
# 5835            NaN            NaN           NaN                    NaN
# 4434            NaN            NaN           NaN                    NaN
# 884             NaN            NaN           NaN                    NaN
# 5833            NaN            NaN           NaN                    NaN
# 5832            NaN            NaN           NaN                    NaN
# 5834            NaN            NaN           NaN                    NaN
# 849             NaN            NaN           NaN                    NaN
# 4433            NaN            NaN           NaN                    NaN
# 1049            NaN            NaN           NaN                    NaN
# 578             NaN            NaN           NaN                    NaN
# 579             NaN            NaN           NaN                    NaN
# 1050            NaN            NaN           NaN                    NaN
# 4432            NaN            NaN           NaN                    NaN
# 5831            NaN            NaN           NaN                    NaN
# 577             NaN            NaN           NaN                    NaN
# 576             NaN            NaN           NaN                    NaN
# 4430            NaN            NaN           NaN                    NaN
#
#       净敞口套期收益       信用减值损失        资产处置收益  归属于母公司其他权益工具持有者的净利润  year
# 33        NaN -280488237.5  1.924118e+07                  NaN  2021
# 32        NaN -224461716.1  4.838127e+07                  NaN  2020
# 31        NaN -216850483.0 -9.665524e+06                  NaN  2019
# 1235      NaN -383451000.0  5.825700e+07                  NaN  2021
# 30        NaN  263817478.0 -3.409186e+06                  NaN  2018
# 1234      NaN -247605000.0 -6.052300e+07                  NaN  2020
# 1233      NaN  -96446000.0 -1.311310e+08                  NaN  2019
# 1232      NaN          NaN -3.493400e+07                  NaN  2018
# 29        NaN          NaN -4.915545e+06                  NaN  2017
# 1231      NaN          NaN  1.327251e+09                  NaN  2017
# 28        NaN          NaN           NaN                  NaN  2016
# 4684      NaN  -28409869.0  1.535058e+08                  NaN  2021
# 3700      NaN -279448586.3  4.911230e+06                  NaN  2019
# 3699      NaN          NaN  6.366293e+05                  NaN  2018
# 1249      NaN -563605119.0  3.175364e+07                  NaN  2020
# 27        NaN          NaN           NaN                  NaN  2015
# 1230      NaN          NaN           NaN                  NaN  2016
# 1246      NaN          NaN  8.473064e+07                  NaN  2017
# 26        NaN          NaN           NaN                  NaN  2014
# 1228      NaN          NaN           NaN                  NaN  2014
# 3695      NaN          NaN           NaN                  NaN  2014
# 1229      NaN          NaN           NaN                  NaN  2015
# 25        NaN          NaN           NaN                  NaN  2013
# 4436      NaN          NaN           NaN                  NaN  2011
# 1227      NaN          NaN           NaN                  NaN  2013
# 3694      NaN          NaN           NaN                  NaN  2013
# 4435      NaN          NaN           NaN                  NaN  2010
# 4437      NaN          NaN           NaN                  NaN  2012
# 3697      NaN          NaN           NaN                  NaN  2016
# 1059      NaN          NaN           NaN                  NaN  2015
# 5837      NaN          NaN           NaN                  NaN  2012
# 24        NaN          NaN           NaN                  NaN  2012
# 5836      NaN          NaN           NaN                  NaN  2011
# 2096      NaN          NaN           NaN                  NaN  2011
# 5835      NaN          NaN           NaN                  NaN  2010
# 4434      NaN          NaN           NaN                  NaN  2009
# 884       NaN          NaN           NaN                  NaN  2010
# 5833      NaN          NaN           NaN                  NaN  2008
# 5832      NaN          NaN           NaN                  NaN  2007
# 5834      NaN          NaN           NaN                  NaN  2009
# 849       NaN          NaN           NaN                  NaN  2009
# 4433      NaN          NaN           NaN                  NaN  2008
# 1049      NaN          NaN           NaN                  NaN  2005
# 578       NaN          NaN           NaN                  NaN  2007
# 579       NaN          NaN           NaN                  NaN  2008
# 1050      NaN          NaN           NaN                  NaN  2006
# 4432      NaN          NaN           NaN                  NaN  2007
# 5831      NaN          NaN           NaN                  NaN  2006
# 577       NaN          NaN           NaN                  NaN  2006
# 576       NaN          NaN           NaN                  NaN  2005
# 4430      NaN          NaN           NaN                  NaN  2005
#
# [51 rows x 73 columns]

# %%
finc.sort_values(by=['营业总收入'], ascending=False).groupby(by=['year'])

# %%
tmp
# Out:
#      m  a  b     c   d   k
# e
# bbb  0  1  5    aa  bb   6
# bbb  0  3  7   NaN  bb   9
# aaa  0  3  9   inf  aa  12
# bbb  0  4  6  test  bb  10

# %%
# 合并数据 - 依据d的数据进行合并
tmp.groupby('d').sum()
# Out:
#     m  a   b   k
# d
# aa  0  3   9  12
# bb  0  8  18  25

# %%
tmp.groupby('d')['a'].sum()
# Out:
# d
# aa    3
# bb    8
# Name: a, dtype: int64

# %% [markdown]
# ### agg

# %% [markdown]
# Aggregate using one or more operations over the specified axis.

# %%
tmp.groupby('d').agg({'k': 'mean', 'a': 'sum'})
# Out:
#             k  a
# d
# aa  12.000000  3
# bb   8.333333  8

# %% [markdown]
# ### transform

# %%
dfx = pd.DataFrame(data=[['a', 1,2], ['b', 2,3], ['a', 1,9], ['b', 3,4]], columns=['aa', 'bb', 'cc'])

# %%
dfx
# Out:
#   aa  bb  cc
# 0  a   1   2
# 1  b   2   3
# 2  a   1   9
# 3  b   3   4

# %%
dfx.groupby(by=['aa'])['bb'].sum().reset_index()
# Out:
#   aa  bb
# 0  a   2
# 1  b   5

# %%
# 为每个相同的项保留计算出来的总结果
dfx.groupby(by=['aa']).transform(sum)
# Out:
#    bb  cc
# 0   2  11
# 1   5   7
# 2   2  11
# 3   5   7

# %% [markdown]
# ### pivot_table

# %%
# 透视表的方式实现, 对不同的列进行不一样的聚合
dfx.pivot_table(values=['bb', 'cc'], index='aa', aggfunc={'bb': 'sum', 'cc': 'mean'})
# Out:
#     bb   cc
# aa
# a    2  5.5
# b    5  3.5

# %% [markdown]
# ### stack

# %%
dfs = pd.DataFrame([
    [178, 'male', 'new york'],
    [174, 'female', 'shanghai'],
    [185, 'male', 'beijing']
], index=['aa', 'bb', 'cc'], columns=['heigh', 'gender', 'city'])

# %%
dfs
# Out:
#     heigh  gender      city
# aa    178    male  new york
# bb    174  female  shanghai
# cc    185    male   beijing

# %% [markdown]
# dfs.stack(level: 'Level' = -1, dropna: 'bool' = True)
#
# Stack the prescribed level(s) from columns to index.
#
# Return a reshaped DataFrame or Series having a multi-level
# index with one or more new inner-most levels compared to the current
# DataFrame. The new inner-most levels are created by pivoting the
# columns of the current dataframe:
#
#   - if the columns have a single level, the output is a Series;
#   - if the columns have multiple levels, the new index
#     level(s) is (are) taken from the prescribed level(s) and
#     the output is a DataFrame.

# %%
dfp = dfs.stack()

# %%
dfp
# Out:
# aa  heigh          178
#     gender        male
#     city      new york
# bb  heigh          174
#     gender      female
#     city      shanghai
# cc  heigh          185
#     gender        male
#     city       beijing
# dtype: object

# %%
dfp.index
# Out:
# MultiIndex([('aa',  'heigh'),
#             ('aa', 'gender'),
#             ('aa',   'city'),
#             ('bb',  'heigh'),
#             ('bb', 'gender'),
#             ('bb',   'city'),
#             ('cc',  'heigh'),
#             ('cc', 'gender'),
#             ('cc',   'city')],
#            )

# %% [markdown]
# ### merge

# %% [markdown]
# df.merge(
#
#     right: 'DataFrame | Series',
#     how: 'str' = 'inner',
#     on: 'IndexLabel | None' = None,
#     left_on: 'IndexLabel | None' = None,
#     right_on: 'IndexLabel | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool' = True,
#     indicator: 'bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'

# %% [markdown]
# how : {'left', 'right', 'outer', 'inner', 'cross'}, default 'inner'
#     Type of merge to be performed.
#
#     * left: use only keys from left frame, similar to a SQL left outer join;
#       preserve key order.
#     * right: use only keys from right frame, similar to a SQL right outer join;
#       preserve key order.
#     * outer: use union of keys from both frames, similar to a SQL full outer
#       join; sort keys lexicographically.
#     * inner: use intersection of keys from both frames, similar to a SQL inner
#       join; preserve the order of the left keys.
#     * cross: creates the cartesian product from both frames, preserves the order
#       of the left keys.

# %%
m = pd.DataFrame(
    {
        'a': ['aa', 'aa', 'bb', 'cc'],
        'b': [1,2,3,4]
    }
)

# %%
n = pd.DataFrame(
    {
        'a': ['dd', 'aa', 'bb', 'aa'],
        'c': [10,22,13,14]
    }
)

# %%
m
# Out:
#     a  b
# 0  aa  1
# 1  aa  2
# 2  bb  3
# 3  cc  4

# %%
n
# Out:
#     a   c
# 0  dd  10
# 1  aa  22
# 2  bb  13
# 3  aa  14

# %%
m.merge(n, on='a', how='left')
# Out:
#     a  b     c
# 0  aa  1  22.0
# 1  aa  1  14.0
# 2  aa  2  22.0
# 3  aa  2  14.0
# 4  bb  3  13.0
# 5  cc  4   NaN

# %%
m.merge(n, on='a', how='inner')
# Out:
#     a  b   c
# 0  aa  1  22
# 1  aa  1  14
# 2  aa  2  22
# 3  aa  2  14
# 4  bb  3  13

# %%
m.merge(n, on='a', how='right')
# Out:
#     a    b   c
# 0  dd  NaN  10
# 1  aa  1.0  22
# 2  aa  2.0  22
# 3  bb  3.0  13
# 4  aa  1.0  14
# 5  aa  2.0  14

# %% [markdown]
# 注意, 当m, n两个`dataframe`, `on`存在相同的项目时, 会出现笛卡尔积的问题
#
# 有别于`excel`中的`vlookup`(检索到对应的值, 即返回)

# %%
m.merge(n, on='a', how='cross')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [194], in <cell line: 1>()
# ----> 1 m.merge(n, on='a', how='cross')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678     # stacklevel chosen to be correct when this is reached via pd.merge
#     679     # (and not DataFrame.join)
#     680     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 682 self._validate_specification()
#     684 cross_col = None
#     685 if self.how == "cross":
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1329, in _MergeOperation._validate_specification(self)
#    1321 if self.how == "cross":
#    1322     if (
#    1323         self.left_index
#    1324         or self.right_index
#    (...)
#    1327         or self.on is not None
#    1328     ):
# -> 1329         raise MergeError(
#    1330             "Can not pass on, right_on, left_on or set right_index=True or "
#    1331             "left_index=True"
#    1332         )
#    1333     return
#    1334 # Hm, any way to make this logic less complicated??
#
# MergeError: Can not pass on, right_on, left_on or set right_index=True or left_index=True

# %%
na = pd.DataFrame(
    {
        'a': ['dd', 'cc', 'bb', 'aa'],
        'b': [10,22,13,14]
    }
)

# %%
nb = pd.DataFrame(
    {
        'a': ['dd', 'cc', 'bb', 'aa'],
        'c': [10,22,13,14]
    }
)

# %%
# 适用于主键不重复的内容

na.merge(nb, on='a', how='left')
# Out:
#     a   b   c
# 0  dd  10  10
# 1  cc  22  22
# 2  bb  13  13
# 3  aa  14  14

# %% [markdown]
# na.join(
#
#     other: 'DataFrame | Series',
#     on: 'IndexLabel | None' = None,
#     how: 'str' = 'left',
#     lsuffix: 'str' = '',
#     rsuffix: 'str' = '',
#     sort: 'bool' = False,
# ) -> 'DataFrame'

# %%
na.join(nb, on='a', how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [203], in <cell line: 1>()
# ----> 1 na.join(nb, on='a', how='left')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9254, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    9100 def join(
#    9101     self,
#    9102     other: DataFrame | Series,
#    (...)
#    9107     sort: bool = False,
#    9108 ) -> DataFrame:
#    9109     """
#    9110     Join columns of another DataFrame.
#    9111
#    (...)
#    9252     5  K1  A5   B1
#    9253     """
# -> 9254     return self._join_compat(
#    9255         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9256     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9285, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9276     if how == "cross":
#    9277         return merge(
#    9278             self,
#    9279             other,
#    (...)
#    9283             sort=sort,
#    9284         )
# -> 9285     return merge(
#    9286         self,
#    9287         other,
#    9288         left_on=on,
#    9289         how=how,
#    9290         left_index=on is None,
#    9291         right_index=True,
#    9292         suffixes=(lsuffix, rsuffix),
#    9293         sort=sort,
#    9294     )
#    9295 else:
#    9296     if on is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:704, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
#     700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
# --> 704 self._maybe_coerce_merge_keys()
#     706 # If argument passed to validate,
#     707 # check if columns specified as unique
#     708 # are in fact unique.
#     709 if validate is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1257, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1251     # unless we are merging non-string-like with string-like
#    1252     elif (
#    1253         inferred_left in string_types and inferred_right not in string_types
#    1254     ) or (
#    1255         inferred_right in string_types and inferred_left not in string_types
#    1256     ):
# -> 1257         raise ValueError(msg)
#    1259 # datetimelikes must match exactly
#    1260 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
nc = na.copy(True)

# %%
nc.columns = ['d', 'e']

# %%
na.join(nc)
# Out:
#     a   b   d   e
# 0  dd  10  dd  10
# 1  cc  22  cc  22
# 2  bb  13  bb  13
# 3  aa  14  aa  14

# %%
pd.concat([na, nc], axis=1)
# Out:
#     a   b   d   e
# 0  dd  10  dd  10
# 1  cc  22  cc  22
# 2  bb  13  bb  13
# 3  aa  14  aa  14
